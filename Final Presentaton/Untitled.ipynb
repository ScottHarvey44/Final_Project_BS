# %%
from IPython.display import Image
#Closing Prices Chart
Image("AMZN_StockChart.png")

# %%
#Moving Average Chart
Image("AMZN_MA.png")

# %%
#Linear Regression Chart
Image("AMZN_LR.png")

# %%
#K Nearest Neighbors Regression Chart
Image("AMZN_KNN.png")

# %%
#Auto Arima Chart
Image("AMZN_ARIMA.png")

# %%
#Prophet Chart
Image("AMZN_Prophet.png")

# %%
#Long Short Term Memory Chart
Image("AMZN_LSTN.png")
