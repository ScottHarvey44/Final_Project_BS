# %% [markdown]
# # Predicting the Stock Market

# %% [markdown]
# ## Disclaimer: Although we made Billions during the process of this project this is not considered investment advice!

# %% [markdown]
# ### Based on the fact that the daily closing price is used for profit and loss calculations we used that as the target variable and created the below chart to make sure it was plotting correctly.

# %%
from IPython.display import Image
#Closing Prices Chart
Image("images/AMZN_StockChart.png")

# %% [markdown]
# ## Moving Average

# %%
#Moving Average RMSE
Image("images/AMZ_moving_average_RMSE.png")

# %%
#Moving Average Chart
Image("images/AMZN_MA.png")

# %% [markdown]
# ### Not the best fit...

# %% [markdown]
# ## Linear Regression

# %%
#Linear Regression RMSE
Image("images/AMZ_linear_regression_RMSE.png")

# %%
#Linear Regression Chart
Image("images/AMZN_LR.png")

# %% [markdown]
# ## Nearest Neighbours

# %%
#K Nearest Neighbors Example Chart
Image("images/Knn_example_chart.png")

# %%
#Nearest Neighbours RMSE
Image("images/AMZ_nearest_neighbors_RMSE.png")

# %%
#K Nearest Neighbors Regression Chart
Image("images/AMZN_KNN.png")

# %% [markdown]
# ### Well that sucked

# %% [markdown]
# ## Auto Arima

# %%
#Auto Arima RMSE
Image("images/Auto_arima_RMSE.png")

# %% [markdown]
# ### Back on track...but ain't no soothsayer

# %%
#Auto Arima Chart
Image("images/AMZN_ARIMA.png")

# %% [markdown]
# ## FaceBook Prophet

# %%
#Prophet RMSE
Image("images/AMZ_fbprophet_RMSE.png")

# %%
#Prophet Chart
Image("images/AMZN_Prophet.png")

# %% [markdown]
# ## Long Short Term Memory

# %%
#LSTM RMSE
Image("images/AMZ_LSTM_RMSE.png")

# %%
#Long Short Term Memory Chart
Image("images/AMZ_LSTM_chart.png")

# %% [markdown]
# # Ecomomic Indicators

# %%
#ISM (6 to 12 month lag time)
Image("images/ISM_writeup.png", width=700, height=500)

# %%
Image("images/Manu_data.png", width=800, height=600)

# %%
Image("images/ISM_trends.png", width=500, height=300)

# %%
Image("images/ISM_index.png")

# %% [markdown]
# ## Building Permits

# %%
#Building Permits

Image("images/Permits_writeup.png", width=700, height=500)

# %%
Image("images/bldg_permits.png")

# %% [markdown]
# # Putting it all together

# %%
Image('images/prediction_with_ISM_overlay.png')

# %% [markdown]
# ## ISM above 50 and decreasing = negative outlook

# %%
Image("images/ISM_index.png")

# %%
Image("images/bldg_permits.png")

# %% [markdown]
# ## Building Permits = neutral outlook

# %% [markdown]
# ### Dow predicition for 4/26/19

# %%
Image("images/dia_prediction.jpg")

# %% [markdown]
# ### Dow Actual

# %%
Image("images/DIA_actual.png")

# %% [markdown]
# ### Amazon predicition for 4/26/19

# %%
Image("images/AMZ_prediction.png")

# %% [markdown]
# ### Actual close price 4/26/19

# %%
Image("images/April_26_AMZ_close.png")
